# %%
import argparse
import json
import mxnet as mx
import tensorflow as tf
from tensorflow.python.framework import graph_util

import numpy as np

from converter import Converter
import os
import time

# %reload_ext autoreload
# %autoreload 2

def main(model_prefix, output_prefix, input_h=128, input_w = 128):
    # Parsing JSON is easier because it contains operator name
    js_model = json.load(open(model_prefix + '-symbol.json', 'r'))
    mx_model, arg_params, aux_params = mx.model.load_checkpoint(model_prefix, 0)
    params = arg_params
    params.update(aux_params)
    tf.reset_default_graph()

    config = tf.ConfigProto(gpu_options=tf.GPUOptions(allow_growth=True))

    a = 0
    with tf.Session(config=config) as sess:
        tf_nodes = dict()
        # Workaround for input node
        input_data = tf.placeholder('float32', (1, input_h, input_w, 3), name='data')
        tf_nodes['data'] = input_data
        nodes = js_model['nodes']
        conv = Converter(tf_nodes, nodes, params)
        for node_idx, node in enumerate(nodes):
            op = node['op']
            print('Parsing node %s with operator %s and index %d' % (node['name'], op, node_idx))
            # Hack for older versions of MxNet
            if 'param' in node:
                node['attrs'] = node['param']
            if op == 'BatchNorm':
                conv.create_bn(node)
            elif op == 'elemwise_add' or op == '_Plus':
                conv.create_elementwise(node)
            elif op == 'Activation':
                conv.create_activation(node)
            elif op == 'SoftmaxOutput':
                conv.create_softmax(node)
            elif op == 'Convolution':
                conv.create_conv(node)
            elif op == 'Pooling':
                conv.create_pooling(node)
            elif op == 'Flatten':
                conv.create_flatten(node)
            elif op == 'FullyConnected':
                conv.create_fc(node)
            elif op == 'L2Normalization':
                conv.create_norm(node)
            elif op == "Concat":
                conv.create_concat(node)
            elif op == "Reshape":
                conv.create_reshape(node)
            elif op == "Crop":
                conv.create_crop(node)
            elif op == "UpSampling":
                conv.create_upsampling(node)
                #conv.create_upsampling_v2(node)
            elif op == "SoftmaxActivation":
                conv.create_softmaxactivation(node)
            elif op == 'null':
                #print("this is just a param, do not create op")
                a += 1
            else:
                print("------------------unsupported op!!!----------------------")
        
        #print("null nodes:", a)

        #test run
        output_node_names = []
        for i in range(len(js_model['heads'])):
            output_node_names.append(nodes[js_model['heads'][i][0]]['name'])
        print("output node names:", output_node_names)
        output_nodes = []
        print("------------------------------Output nodes:--------------------------")
        for i in range(len(output_node_names)):
            print(tf_nodes[output_node_names[i]])
            output_nodes.append(tf_nodes[output_node_names[i]])
        
        # test define my own conv layer after
        output_nodes_rev = []
        #################### stride 32 ################################
        output_nodes_rev.append(output_nodes[0])
        tmp = output_nodes[3]
        with tf.variable_scope("", reuse=tf.AUTO_REUSE):
            bbox_stride32_w = tf.get_variable("face_rpn_bbox_pred_stride32_weight")
            bbox_stride32_b = tf.get_variable("face_rpn_bbox_pred_stride32_bias")
            landmark_stride32_w = tf.get_variable("face_rpn_landmark_pred_stride32_weight")
            landmark_stride32_b = tf.get_variable("face_rpn_landmark_pred_stride32_bias")
            #print("shape: ", bbox_stride32_w.shape, bbox_stride32_b.shape)
        tmp1 = tf.nn.conv2d(tmp, bbox_stride32_w, [1, 1, 1, 1], padding='VALID')
        tmp1 = tf.add(tmp1, bbox_stride32_b, name = "face_rpn_bbox_pred_stride32_rev")

        tmp2 = tf.nn.conv2d(tmp, landmark_stride32_w, [1, 1, 1, 1], padding='VALID')
        tmp2 = tf.add(tmp2, landmark_stride32_b, name = "face_rpn_landmark_pred_stride32_rev")

        output_nodes_rev.append(tmp1)
        output_nodes_rev.append(tmp2)
        
        #################### stride 16 ################################
        output_nodes_rev.append(output_nodes[1])
        tmp = output_nodes[4]
        with tf.variable_scope("", reuse=tf.AUTO_REUSE):
            bbox_stride16_w = tf.get_variable("face_rpn_bbox_pred_stride16_weight")
            bbox_stride16_b = tf.get_variable("face_rpn_bbox_pred_stride16_bias")
            landmark_stride16_w = tf.get_variable("face_rpn_landmark_pred_stride16_weight")
            landmark_stride16_b = tf.get_variable("face_rpn_landmark_pred_stride16_bias")
            
        tmp1 = tf.nn.conv2d(tmp, bbox_stride16_w, [1, 1, 1, 1], padding='VALID')
        tmp1 = tf.add(tmp1, bbox_stride16_b, name = "face_rpn_bbox_pred_stride16_rev")

        tmp2 = tf.nn.conv2d(tmp, landmark_stride16_w, [1, 1, 1, 1], padding='VALID')
        tmp2 = tf.add(tmp2, landmark_stride16_b, name = "face_rpn_landmark_pred_stride16_rev")

        output_nodes_rev.append(tmp1)
        output_nodes_rev.append(tmp2)
        
        #################### stride 8 ################################
        output_nodes_rev.append(output_nodes[2])
        tmp = output_nodes[5]
        with tf.variable_scope("", reuse=tf.AUTO_REUSE):
            bbox_stride8_w = tf.get_variable("face_rpn_bbox_pred_stride8_weight")
            bbox_stride8_b = tf.get_variable("face_rpn_bbox_pred_stride8_bias")
            landmark_stride8_w = tf.get_variable("face_rpn_landmark_pred_stride8_weight")
            landmark_stride8_b = tf.get_variable("face_rpn_landmark_pred_stride8_bias")
            
        tmp1 = tf.nn.conv2d(tmp, bbox_stride8_w, [1, 1, 1, 1], padding='VALID')
        tmp1 = tf.add(tmp1, bbox_stride8_b, name = "face_rpn_bbox_pred_stride8_rev")

        tmp2 = tf.nn.conv2d(tmp, landmark_stride8_w, [1, 1, 1, 1], padding='VALID')
        tmp2 = tf.add(tmp2, landmark_stride8_b, name = "face_rpn_landmark_pred_stride8_rev")

        output_nodes_rev.append(tmp1)
        output_nodes_rev.append(tmp2)
        
        print("------------------------output nodes rev:----------------------")
        for node in output_nodes_rev:
            print(node)

        print("---------------------test inference-------------------")
        for i in range(5):
            start = time.time()
            out = sess.run(output_nodes_rev, feed_dict = {input_data: np.zeros([1,input_h,input_w,3])})
            end = time.time()
            print("inference time: %.6f" %(end-start))
        for i in range(len(out)):
            print("output node shape:", out[i].transpose(0,3,1,2).shape)
        #'''
        
        g_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
        print("number of variables (trainable & global):", len(g_vars))
        saver = tf.train.Saver(g_vars)
        saver.save(sess, os.path.join("./checkpoint", "mnet.25-%dx%d"%(input_h, input_w)), write_meta_graph=True)
# Out:
# /home/johnyi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/johnyi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/johnyi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/johnyi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/johnyi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/johnyi/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
mx_prefix = "models/mnet.25"
tf_prefix = "xxx"
input_h = 1080
input_w = 1920
main(mx_prefix, tf_prefix, input_h, input_w)
# Out:
# Parsing node data with operator null and index 0
# Parsing node mobilenet0_conv0_weight with operator null and index 1
# Parsing node mobilenet0_conv0_fwd with operator Convolution and index 2
# WARNING:tensorflow:From /home/johnyi/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Parsing node mobilenet0_batchnorm0_gamma with operator null and index 3
# Parsing node mobilenet0_batchnorm0_beta with operator null and index 4
# Parsing node mobilenet0_batchnorm0_running_mean with operator null and index 5
# Parsing node mobilenet0_batchnorm0_running_var with operator null and index 6
# Parsing node mobilenet0_batchnorm0_fwd with operator BatchNorm and index 7
# Parsing node mobilenet0_relu0_fwd with operator Activation and index 8
# Parsing node mobilenet0_conv1_weight with operator null and index 9
# Parsing node mobilenet0_conv1_fwd with operator Convolution and index 10
# Parsing node mobilenet0_batchnorm1_gamma with operator null and index 11
# Parsing node mobilenet0_batchnorm1_beta with operator null and index 12
# Parsing node mobilenet0_batchnorm1_running_mean with operator null and index 13
# Parsing node mobilenet0_batchnorm1_running_var with operator null and index 14
# Parsing node mobilenet0_batchnorm1_fwd with operator BatchNorm and index 15
# Parsing node mobilenet0_relu1_fwd with operator Activation and index 16
# Parsing node mobilenet0_conv2_weight with operator null and index 17
# Parsing node mobilenet0_conv2_fwd with operator Convolution and index 18
# Parsing node mobilenet0_batchnorm2_gamma with operator null and index 19
# Parsing node mobilenet0_batchnorm2_beta with operator null and index 20
# Parsing node mobilenet0_batchnorm2_running_mean with operator null and index 21
# Parsing node mobilenet0_batchnorm2_running_var with operator null and index 22
# Parsing node mobilenet0_batchnorm2_fwd with operator BatchNorm and index 23
# Parsing node mobilenet0_relu2_fwd with operator Activation and index 24
# Parsing node mobilenet0_conv3_weight with operator null and index 25
# Parsing node mobilenet0_conv3_fwd with operator Convolution and index 26
# Parsing node mobilenet0_batchnorm3_gamma with operator null and index 27
# Parsing node mobilenet0_batchnorm3_beta with operator null and index 28
# Parsing node mobilenet0_batchnorm3_running_mean with operator null and index 29
# Parsing node mobilenet0_batchnorm3_running_var with operator null and index 30
# Parsing node mobilenet0_batchnorm3_fwd with operator BatchNorm and index 31
# Parsing node mobilenet0_relu3_fwd with operator Activation and index 32
# Parsing node mobilenet0_conv4_weight with operator null and index 33
# Parsing node mobilenet0_conv4_fwd with operator Convolution and index 34
# Parsing node mobilenet0_batchnorm4_gamma with operator null and index 35
# Parsing node mobilenet0_batchnorm4_beta with operator null and index 36
# Parsing node mobilenet0_batchnorm4_running_mean with operator null and index 37
# Parsing node mobilenet0_batchnorm4_running_var with operator null and index 38
# Parsing node mobilenet0_batchnorm4_fwd with operator BatchNorm and index 39
# Parsing node mobilenet0_relu4_fwd with operator Activation and index 40
# Parsing node mobilenet0_conv5_weight with operator null and index 41
# Parsing node mobilenet0_conv5_fwd with operator Convolution and index 42
# Parsing node mobilenet0_batchnorm5_gamma with operator null and index 43
# Parsing node mobilenet0_batchnorm5_beta with operator null and index 44
# Parsing node mobilenet0_batchnorm5_running_mean with operator null and index 45
# Parsing node mobilenet0_batchnorm5_running_var with operator null and index 46
# Parsing node mobilenet0_batchnorm5_fwd with operator BatchNorm and index 47
# Parsing node mobilenet0_relu5_fwd with operator Activation and index 48
# Parsing node mobilenet0_conv6_weight with operator null and index 49
# Parsing node mobilenet0_conv6_fwd with operator Convolution and index 50
# Parsing node mobilenet0_batchnorm6_gamma with operator null and index 51
# Parsing node mobilenet0_batchnorm6_beta with operator null and index 52
# Parsing node mobilenet0_batchnorm6_running_mean with operator null and index 53
# Parsing node mobilenet0_batchnorm6_running_var with operator null and index 54
# Parsing node mobilenet0_batchnorm6_fwd with operator BatchNorm and index 55
# Parsing node mobilenet0_relu6_fwd with operator Activation and index 56
# Parsing node mobilenet0_conv7_weight with operator null and index 57
# Parsing node mobilenet0_conv7_fwd with operator Convolution and index 58
# Parsing node mobilenet0_batchnorm7_gamma with operator null and index 59
# Parsing node mobilenet0_batchnorm7_beta with operator null and index 60
# Parsing node mobilenet0_batchnorm7_running_mean with operator null and index 61
# Parsing node mobilenet0_batchnorm7_running_var with operator null and index 62
# Parsing node mobilenet0_batchnorm7_fwd with operator BatchNorm and index 63
# Parsing node mobilenet0_relu7_fwd with operator Activation and index 64
# Parsing node mobilenet0_conv8_weight with operator null and index 65
# Parsing node mobilenet0_conv8_fwd with operator Convolution and index 66
# Parsing node mobilenet0_batchnorm8_gamma with operator null and index 67
# Parsing node mobilenet0_batchnorm8_beta with operator null and index 68
# Parsing node mobilenet0_batchnorm8_running_mean with operator null and index 69
# Parsing node mobilenet0_batchnorm8_running_var with operator null and index 70
# Parsing node mobilenet0_batchnorm8_fwd with operator BatchNorm and index 71
# Parsing node mobilenet0_relu8_fwd with operator Activation and index 72
# Parsing node mobilenet0_conv9_weight with operator null and index 73
# Parsing node mobilenet0_conv9_fwd with operator Convolution and index 74
# Parsing node mobilenet0_batchnorm9_gamma with operator null and index 75
# Parsing node mobilenet0_batchnorm9_beta with operator null and index 76
# Parsing node mobilenet0_batchnorm9_running_mean with operator null and index 77
# Parsing node mobilenet0_batchnorm9_running_var with operator null and index 78
# Parsing node mobilenet0_batchnorm9_fwd with operator BatchNorm and index 79
# Parsing node mobilenet0_relu9_fwd with operator Activation and index 80
# Parsing node mobilenet0_conv10_weight with operator null and index 81
# Parsing node mobilenet0_conv10_fwd with operator Convolution and index 82
# Parsing node mobilenet0_batchnorm10_gamma with operator null and index 83
# Parsing node mobilenet0_batchnorm10_beta with operator null and index 84
# Parsing node mobilenet0_batchnorm10_running_mean with operator null and index 85
# Parsing node mobilenet0_batchnorm10_running_var with operator null and index 86
# Parsing node mobilenet0_batchnorm10_fwd with operator BatchNorm and index 87
# Parsing node mobilenet0_relu10_fwd with operator Activation and index 88
# Parsing node mobilenet0_conv11_weight with operator null and index 89
# Parsing node mobilenet0_conv11_fwd with operator Convolution and index 90
# Parsing node mobilenet0_batchnorm11_gamma with operator null and index 91
# Parsing node mobilenet0_batchnorm11_beta with operator null and index 92
# Parsing node mobilenet0_batchnorm11_running_mean with operator null and index 93
# Parsing node mobilenet0_batchnorm11_running_var with operator null and index 94
# Parsing node mobilenet0_batchnorm11_fwd with operator BatchNorm and index 95
# Parsing node mobilenet0_relu11_fwd with operator Activation and index 96
# Parsing node mobilenet0_conv12_weight with operator null and index 97
# Parsing node mobilenet0_conv12_fwd with operator Convolution and index 98
# Parsing node mobilenet0_batchnorm12_gamma with operator null and index 99
# Parsing node mobilenet0_batchnorm12_beta with operator null and index 100
# Parsing node mobilenet0_batchnorm12_running_mean with operator null and index 101
# Parsing node mobilenet0_batchnorm12_running_var with operator null and index 102
# Parsing node mobilenet0_batchnorm12_fwd with operator BatchNorm and index 103
# Parsing node mobilenet0_relu12_fwd with operator Activation and index 104
# Parsing node mobilenet0_conv13_weight with operator null and index 105
# Parsing node mobilenet0_conv13_fwd with operator Convolution and index 106
# Parsing node mobilenet0_batchnorm13_gamma with operator null and index 107
# Parsing node mobilenet0_batchnorm13_beta with operator null and index 108
# Parsing node mobilenet0_batchnorm13_running_mean with operator null and index 109
# Parsing node mobilenet0_batchnorm13_running_var with operator null and index 110
# Parsing node mobilenet0_batchnorm13_fwd with operator BatchNorm and index 111
# Parsing node mobilenet0_relu13_fwd with operator Activation and index 112
# Parsing node mobilenet0_conv14_weight with operator null and index 113
# Parsing node mobilenet0_conv14_fwd with operator Convolution and index 114
# Parsing node mobilenet0_batchnorm14_gamma with operator null and index 115
# Parsing node mobilenet0_batchnorm14_beta with operator null and index 116
# Parsing node mobilenet0_batchnorm14_running_mean with operator null and index 117
# Parsing node mobilenet0_batchnorm14_running_var with operator null and index 118
# Parsing node mobilenet0_batchnorm14_fwd with operator BatchNorm and index 119
# Parsing node mobilenet0_relu14_fwd with operator Activation and index 120
# Parsing node mobilenet0_conv15_weight with operator null and index 121
# Parsing node mobilenet0_conv15_fwd with operator Convolution and index 122
# Parsing node mobilenet0_batchnorm15_gamma with operator null and index 123
# Parsing node mobilenet0_batchnorm15_beta with operator null and index 124
# Parsing node mobilenet0_batchnorm15_running_mean with operator null and index 125
# Parsing node mobilenet0_batchnorm15_running_var with operator null and index 126
# Parsing node mobilenet0_batchnorm15_fwd with operator BatchNorm and index 127
# Parsing node mobilenet0_relu15_fwd with operator Activation and index 128
# Parsing node mobilenet0_conv16_weight with operator null and index 129
# Parsing node mobilenet0_conv16_fwd with operator Convolution and index 130
# Parsing node mobilenet0_batchnorm16_gamma with operator null and index 131
# Parsing node mobilenet0_batchnorm16_beta with operator null and index 132
# Parsing node mobilenet0_batchnorm16_running_mean with operator null and index 133
# Parsing node mobilenet0_batchnorm16_running_var with operator null and index 134
# Parsing node mobilenet0_batchnorm16_fwd with operator BatchNorm and index 135
# Parsing node mobilenet0_relu16_fwd with operator Activation and index 136
# Parsing node mobilenet0_conv17_weight with operator null and index 137
# Parsing node mobilenet0_conv17_fwd with operator Convolution and index 138
# Parsing node mobilenet0_batchnorm17_gamma with operator null and index 139
# Parsing node mobilenet0_batchnorm17_beta with operator null and index 140
# Parsing node mobilenet0_batchnorm17_running_mean with operator null and index 141
# Parsing node mobilenet0_batchnorm17_running_var with operator null and index 142
# Parsing node mobilenet0_batchnorm17_fwd with operator BatchNorm and index 143
# Parsing node mobilenet0_relu17_fwd with operator Activation and index 144
# Parsing node mobilenet0_conv18_weight with operator null and index 145
# Parsing node mobilenet0_conv18_fwd with operator Convolution and index 146
# Parsing node mobilenet0_batchnorm18_gamma with operator null and index 147
# Parsing node mobilenet0_batchnorm18_beta with operator null and index 148
# Parsing node mobilenet0_batchnorm18_running_mean with operator null and index 149
# Parsing node mobilenet0_batchnorm18_running_var with operator null and index 150
# Parsing node mobilenet0_batchnorm18_fwd with operator BatchNorm and index 151
# Parsing node mobilenet0_relu18_fwd with operator Activation and index 152
# Parsing node mobilenet0_conv19_weight with operator null and index 153
# Parsing node mobilenet0_conv19_fwd with operator Convolution and index 154
# Parsing node mobilenet0_batchnorm19_gamma with operator null and index 155
# Parsing node mobilenet0_batchnorm19_beta with operator null and index 156
# Parsing node mobilenet0_batchnorm19_running_mean with operator null and index 157
# Parsing node mobilenet0_batchnorm19_running_var with operator null and index 158
# Parsing node mobilenet0_batchnorm19_fwd with operator BatchNorm and index 159
# Parsing node mobilenet0_relu19_fwd with operator Activation and index 160
# Parsing node mobilenet0_conv20_weight with operator null and index 161
# Parsing node mobilenet0_conv20_fwd with operator Convolution and index 162
# Parsing node mobilenet0_batchnorm20_gamma with operator null and index 163
# Parsing node mobilenet0_batchnorm20_beta with operator null and index 164
# Parsing node mobilenet0_batchnorm20_running_mean with operator null and index 165
# Parsing node mobilenet0_batchnorm20_running_var with operator null and index 166
# Parsing node mobilenet0_batchnorm20_fwd with operator BatchNorm and index 167
# Parsing node mobilenet0_relu20_fwd with operator Activation and index 168
# Parsing node mobilenet0_conv21_weight with operator null and index 169
# Parsing node mobilenet0_conv21_fwd with operator Convolution and index 170
# Parsing node mobilenet0_batchnorm21_gamma with operator null and index 171
# Parsing node mobilenet0_batchnorm21_beta with operator null and index 172
# Parsing node mobilenet0_batchnorm21_running_mean with operator null and index 173
# Parsing node mobilenet0_batchnorm21_running_var with operator null and index 174
# Parsing node mobilenet0_batchnorm21_fwd with operator BatchNorm and index 175
# Parsing node mobilenet0_relu21_fwd with operator Activation and index 176
# Parsing node mobilenet0_conv22_weight with operator null and index 177
# Parsing node mobilenet0_conv22_fwd with operator Convolution and index 178
# Parsing node mobilenet0_batchnorm22_gamma with operator null and index 179
# Parsing node mobilenet0_batchnorm22_beta with operator null and index 180
# Parsing node mobilenet0_batchnorm22_running_mean with operator null and index 181
# Parsing node mobilenet0_batchnorm22_running_var with operator null and index 182
# Parsing node mobilenet0_batchnorm22_fwd with operator BatchNorm and index 183
# Parsing node mobilenet0_relu22_fwd with operator Activation and index 184
# Parsing node mobilenet0_conv23_weight with operator null and index 185
# Parsing node mobilenet0_conv23_fwd with operator Convolution and index 186
# Parsing node mobilenet0_batchnorm23_gamma with operator null and index 187
# Parsing node mobilenet0_batchnorm23_beta with operator null and index 188
# Parsing node mobilenet0_batchnorm23_running_mean with operator null and index 189
# Parsing node mobilenet0_batchnorm23_running_var with operator null and index 190
# Parsing node mobilenet0_batchnorm23_fwd with operator BatchNorm and index 191
# Parsing node mobilenet0_relu23_fwd with operator Activation and index 192
# Parsing node mobilenet0_conv24_weight with operator null and index 193
# Parsing node mobilenet0_conv24_fwd with operator Convolution and index 194
# Parsing node mobilenet0_batchnorm24_gamma with operator null and index 195
# Parsing node mobilenet0_batchnorm24_beta with operator null and index 196
# Parsing node mobilenet0_batchnorm24_running_mean with operator null and index 197
# Parsing node mobilenet0_batchnorm24_running_var with operator null and index 198
# Parsing node mobilenet0_batchnorm24_fwd with operator BatchNorm and index 199
# Parsing node mobilenet0_relu24_fwd with operator Activation and index 200
# Parsing node mobilenet0_conv25_weight with operator null and index 201
# Parsing node mobilenet0_conv25_fwd with operator Convolution and index 202
# Parsing node mobilenet0_batchnorm25_gamma with operator null and index 203
# Parsing node mobilenet0_batchnorm25_beta with operator null and index 204
# Parsing node mobilenet0_batchnorm25_running_mean with operator null and index 205
# Parsing node mobilenet0_batchnorm25_running_var with operator null and index 206
# Parsing node mobilenet0_batchnorm25_fwd with operator BatchNorm and index 207
# Parsing node mobilenet0_relu25_fwd with operator Activation and index 208
# Parsing node mobilenet0_conv26_weight with operator null and index 209
# Parsing node mobilenet0_conv26_fwd with operator Convolution and index 210
# Parsing node mobilenet0_batchnorm26_gamma with operator null and index 211
# Parsing node mobilenet0_batchnorm26_beta with operator null and index 212
# Parsing node mobilenet0_batchnorm26_running_mean with operator null and index 213
# Parsing node mobilenet0_batchnorm26_running_var with operator null and index 214
# Parsing node mobilenet0_batchnorm26_fwd with operator BatchNorm and index 215
# Parsing node mobilenet0_relu26_fwd with operator Activation and index 216
# Parsing node rf_c3_lateral_weight with operator null and index 217
# Parsing node rf_c3_lateral_bias with operator null and index 218
# Parsing node rf_c3_lateral with operator Convolution and index 219
# Parsing node rf_c3_lateral_bn_gamma with operator null and index 220
# Parsing node rf_c3_lateral_bn_beta with operator null and index 221
# Parsing node rf_c3_lateral_bn_moving_mean with operator null and index 222
# Parsing node rf_c3_lateral_bn_moving_var with operator null and index 223
# Parsing node rf_c3_lateral_bn with operator BatchNorm and index 224
# Parsing node rf_c3_lateral_relu with operator Activation and index 225
# Parsing node rf_c3_det_conv1_weight with operator null and index 226
# Parsing node rf_c3_det_conv1_bias with operator null and index 227
# Parsing node rf_c3_det_conv1 with operator Convolution and index 228
# Parsing node rf_c3_det_conv1_bn_gamma with operator null and index 229
# Parsing node rf_c3_det_conv1_bn_beta with operator null and index 230
# Parsing node rf_c3_det_conv1_bn_moving_mean with operator null and index 231
# Parsing node rf_c3_det_conv1_bn_moving_var with operator null and index 232
# Parsing node rf_c3_det_conv1_bn with operator BatchNorm and index 233
# Parsing node rf_c3_det_context_conv1_weight with operator null and index 234
# Parsing node rf_c3_det_context_conv1_bias with operator null and index 235
# Parsing node rf_c3_det_context_conv1 with operator Convolution and index 236
# Parsing node rf_c3_det_context_conv1_bn_gamma with operator null and index 237
# Parsing node rf_c3_det_context_conv1_bn_beta with operator null and index 238
# Parsing node rf_c3_det_context_conv1_bn_moving_mean with operator null and index 239
# Parsing node rf_c3_det_context_conv1_bn_moving_var with operator null and index 240
# Parsing node rf_c3_det_context_conv1_bn with operator BatchNorm and index 241
# Parsing node rf_c3_det_context_conv1_relu with operator Activation and index 242
# Parsing node rf_c3_det_context_conv2_weight with operator null and index 243
# Parsing node rf_c3_det_context_conv2_bias with operator null and index 244
# Parsing node rf_c3_det_context_conv2 with operator Convolution and index 245
# Parsing node rf_c3_det_context_conv2_bn_gamma with operator null and index 246
# Parsing node rf_c3_det_context_conv2_bn_beta with operator null and index 247
# Parsing node rf_c3_det_context_conv2_bn_moving_mean with operator null and index 248
# Parsing node rf_c3_det_context_conv2_bn_moving_var with operator null and index 249
# Parsing node rf_c3_det_context_conv2_bn with operator BatchNorm and index 250
# Parsing node rf_c3_det_context_conv3_1_weight with operator null and index 251
# Parsing node rf_c3_det_context_conv3_1_bias with operator null and index 252
# Parsing node rf_c3_det_context_conv3_1 with operator Convolution and index 253
# Parsing node rf_c3_det_context_conv3_1_bn_gamma with operator null and index 254
# Parsing node rf_c3_det_context_conv3_1_bn_beta with operator null and index 255
# Parsing node rf_c3_det_context_conv3_1_bn_moving_mean with operator null and index 256
# Parsing node rf_c3_det_context_conv3_1_bn_moving_var with operator null and index 257
# Parsing node rf_c3_det_context_conv3_1_bn with operator BatchNorm and index 258
# Parsing node rf_c3_det_context_conv3_1_relu with operator Activation and index 259
# Parsing node rf_c3_det_context_conv3_2_weight with operator null and index 260
# Parsing node rf_c3_det_context_conv3_2_bias with operator null and index 261
# Parsing node rf_c3_det_context_conv3_2 with operator Convolution and index 262
# Parsing node rf_c3_det_context_conv3_2_bn_gamma with operator null and index 263
# Parsing node rf_c3_det_context_conv3_2_bn_beta with operator null and index 264
# Parsing node rf_c3_det_context_conv3_2_bn_moving_mean with operator null and index 265
# Parsing node rf_c3_det_context_conv3_2_bn_moving_var with operator null and index 266
# Parsing node rf_c3_det_context_conv3_2_bn with operator BatchNorm and index 267
# Parsing node rf_c3_det_concat with operator Concat and index 268
# Parsing node rf_c3_det_concat_relu with operator Activation and index 269
# Parsing node face_rpn_cls_score_stride32_weight with operator null and index 270
# Parsing node face_rpn_cls_score_stride32_bias with operator null and index 271
# Parsing node face_rpn_cls_score_stride32 with operator Convolution and index 272
# Parsing node face_rpn_cls_score_reshape_stride32 with operator Reshape and index 273
# Parsing node face_rpn_cls_prob_stride32 with operator SoftmaxActivation and index 274
# softmax input: Tensor("face_rpn_cls_score_reshape_stride32:0", shape=(1, 68, 60, 2), dtype=float32)
# Parsing node face_rpn_cls_prob_reshape_stride32 with operator Reshape and index 275
# Parsing node face_rpn_bbox_pred_stride32_weight with operator null and index 276
# Parsing node face_rpn_bbox_pred_stride32_bias with operator null and index 277
# Parsing node face_rpn_bbox_pred_stride32 with operator Convolution and index 278
# Parsing node face_rpn_landmark_pred_stride32_weight with operator null and index 279
# Parsing node face_rpn_landmark_pred_stride32_bias with operator null and index 280
# Parsing node face_rpn_landmark_pred_stride32 with operator Convolution and index 281
# Parsing node rf_c2_lateral_weight with operator null and index 282
# Parsing node rf_c2_lateral_bias with operator null and index 283
# Parsing node rf_c2_lateral with operator Convolution and index 284
# Parsing node rf_c2_lateral_bn_gamma with operator null and index 285
# Parsing node rf_c2_lateral_bn_beta with operator null and index 286
# Parsing node rf_c2_lateral_bn_moving_mean with operator null and index 287
# Parsing node rf_c2_lateral_bn_moving_var with operator null and index 288
# Parsing node rf_c2_lateral_bn with operator BatchNorm and index 289
# Parsing node rf_c2_lateral_relu with operator Activation and index 290
# Parsing node rf_c3_upsampling with operator UpSampling and index 291
# Parsing node crop0 with operator Crop and index 292
# Parsing node plus0 with operator elemwise_add and index 293
# -------------adding just 2 nodes, replace with tf.add-------------------
# Parsing node rf_c2_aggr_weight with operator null and index 294
# Parsing node rf_c2_aggr_bias with operator null and index 295
# Parsing node rf_c2_aggr with operator Convolution and index 296
# Parsing node rf_c2_aggr_bn_gamma with operator null and index 297
# Parsing node rf_c2_aggr_bn_beta with operator null and index 298
# Parsing node rf_c2_aggr_bn_moving_mean with operator null and index 299
# Parsing node rf_c2_aggr_bn_moving_var with operator null and index 300
# Parsing node rf_c2_aggr_bn with operator BatchNorm and index 301
# Parsing node rf_c2_aggr_relu with operator Activation and index 302
# Parsing node rf_c2_det_conv1_weight with operator null and index 303
# Parsing node rf_c2_det_conv1_bias with operator null and index 304
# Parsing node rf_c2_det_conv1 with operator Convolution and index 305
# Parsing node rf_c2_det_conv1_bn_gamma with operator null and index 306
# Parsing node rf_c2_det_conv1_bn_beta with operator null and index 307
# Parsing node rf_c2_det_conv1_bn_moving_mean with operator null and index 308
# Parsing node rf_c2_det_conv1_bn_moving_var with operator null and index 309
# Parsing node rf_c2_det_conv1_bn with operator BatchNorm and index 310
# Parsing node rf_c2_det_context_conv1_weight with operator null and index 311
# Parsing node rf_c2_det_context_conv1_bias with operator null and index 312
# Parsing node rf_c2_det_context_conv1 with operator Convolution and index 313
# Parsing node rf_c2_det_context_conv1_bn_gamma with operator null and index 314
# Parsing node rf_c2_det_context_conv1_bn_beta with operator null and index 315
# Parsing node rf_c2_det_context_conv1_bn_moving_mean with operator null and index 316
# Parsing node rf_c2_det_context_conv1_bn_moving_var with operator null and index 317
# Parsing node rf_c2_det_context_conv1_bn with operator BatchNorm and index 318
# Parsing node rf_c2_det_context_conv1_relu with operator Activation and index 319
# Parsing node rf_c2_det_context_conv2_weight with operator null and index 320
# Parsing node rf_c2_det_context_conv2_bias with operator null and index 321
# Parsing node rf_c2_det_context_conv2 with operator Convolution and index 322
# Parsing node rf_c2_det_context_conv2_bn_gamma with operator null and index 323
# Parsing node rf_c2_det_context_conv2_bn_beta with operator null and index 324
# Parsing node rf_c2_det_context_conv2_bn_moving_mean with operator null and index 325
# Parsing node rf_c2_det_context_conv2_bn_moving_var with operator null and index 326
# Parsing node rf_c2_det_context_conv2_bn with operator BatchNorm and index 327
# Parsing node rf_c2_det_context_conv3_1_weight with operator null and index 328
# Parsing node rf_c2_det_context_conv3_1_bias with operator null and index 329
# Parsing node rf_c2_det_context_conv3_1 with operator Convolution and index 330
# Parsing node rf_c2_det_context_conv3_1_bn_gamma with operator null and index 331
# Parsing node rf_c2_det_context_conv3_1_bn_beta with operator null and index 332
# Parsing node rf_c2_det_context_conv3_1_bn_moving_mean with operator null and index 333
# Parsing node rf_c2_det_context_conv3_1_bn_moving_var with operator null and index 334
# Parsing node rf_c2_det_context_conv3_1_bn with operator BatchNorm and index 335
# Parsing node rf_c2_det_context_conv3_1_relu with operator Activation and index 336
# Parsing node rf_c2_det_context_conv3_2_weight with operator null and index 337
# Parsing node rf_c2_det_context_conv3_2_bias with operator null and index 338
# Parsing node rf_c2_det_context_conv3_2 with operator Convolution and index 339
# Parsing node rf_c2_det_context_conv3_2_bn_gamma with operator null and index 340
# Parsing node rf_c2_det_context_conv3_2_bn_beta with operator null and index 341
# Parsing node rf_c2_det_context_conv3_2_bn_moving_mean with operator null and index 342
# Parsing node rf_c2_det_context_conv3_2_bn_moving_var with operator null and index 343
# Parsing node rf_c2_det_context_conv3_2_bn with operator BatchNorm and index 344
# Parsing node rf_c2_det_concat with operator Concat and index 345
# Parsing node rf_c2_det_concat_relu with operator Activation and index 346
# Parsing node face_rpn_cls_score_stride16_weight with operator null and index 347
# Parsing node face_rpn_cls_score_stride16_bias with operator null and index 348
# Parsing node face_rpn_cls_score_stride16 with operator Convolution and index 349
# Parsing node face_rpn_cls_score_reshape_stride16 with operator Reshape and index 350
# Parsing node face_rpn_cls_prob_stride16 with operator SoftmaxActivation and index 351
# softmax input: Tensor("face_rpn_cls_score_reshape_stride16:0", shape=(1, 136, 120, 2), dtype=float32)
# Parsing node face_rpn_cls_prob_reshape_stride16 with operator Reshape and index 352
# Parsing node face_rpn_bbox_pred_stride16_weight with operator null and index 353
# Parsing node face_rpn_bbox_pred_stride16_bias with operator null and index 354
# Parsing node face_rpn_bbox_pred_stride16 with operator Convolution and index 355
# Parsing node face_rpn_landmark_pred_stride16_weight with operator null and index 356
# Parsing node face_rpn_landmark_pred_stride16_bias with operator null and index 357
# Parsing node face_rpn_landmark_pred_stride16 with operator Convolution and index 358
# Parsing node rf_c1_red_conv_weight with operator null and index 359
# Parsing node rf_c1_red_conv_bias with operator null and index 360
# Parsing node rf_c1_red_conv with operator Convolution and index 361
# Parsing node rf_c1_red_conv_bn_gamma with operator null and index 362
# Parsing node rf_c1_red_conv_bn_beta with operator null and index 363
# Parsing node rf_c1_red_conv_bn_moving_mean with operator null and index 364
# Parsing node rf_c1_red_conv_bn_moving_var with operator null and index 365
# Parsing node rf_c1_red_conv_bn with operator BatchNorm and index 366
# Parsing node rf_c1_red_conv_relu with operator Activation and index 367
# Parsing node rf_c2_upsampling with operator UpSampling and index 368
# Parsing node crop1 with operator Crop and index 369
# Parsing node plus1 with operator elemwise_add and index 370
# -------------adding just 2 nodes, replace with tf.add-------------------
# Parsing node rf_c1_aggr_weight with operator null and index 371
# Parsing node rf_c1_aggr_bias with operator null and index 372
# Parsing node rf_c1_aggr with operator Convolution and index 373
# Parsing node rf_c1_aggr_bn_gamma with operator null and index 374
# Parsing node rf_c1_aggr_bn_beta with operator null and index 375
# Parsing node rf_c1_aggr_bn_moving_mean with operator null and index 376
# Parsing node rf_c1_aggr_bn_moving_var with operator null and index 377
# Parsing node rf_c1_aggr_bn with operator BatchNorm and index 378
# Parsing node rf_c1_aggr_relu with operator Activation and index 379
# Parsing node rf_c1_det_conv1_weight with operator null and index 380
# Parsing node rf_c1_det_conv1_bias with operator null and index 381
# Parsing node rf_c1_det_conv1 with operator Convolution and index 382
# Parsing node rf_c1_det_conv1_bn_gamma with operator null and index 383
# Parsing node rf_c1_det_conv1_bn_beta with operator null and index 384
# Parsing node rf_c1_det_conv1_bn_moving_mean with operator null and index 385
# Parsing node rf_c1_det_conv1_bn_moving_var with operator null and index 386
# Parsing node rf_c1_det_conv1_bn with operator BatchNorm and index 387
# Parsing node rf_c1_det_context_conv1_weight with operator null and index 388
# Parsing node rf_c1_det_context_conv1_bias with operator null and index 389
# Parsing node rf_c1_det_context_conv1 with operator Convolution and index 390
# Parsing node rf_c1_det_context_conv1_bn_gamma with operator null and index 391
# Parsing node rf_c1_det_context_conv1_bn_beta with operator null and index 392
# Parsing node rf_c1_det_context_conv1_bn_moving_mean with operator null and index 393
# Parsing node rf_c1_det_context_conv1_bn_moving_var with operator null and index 394
# Parsing node rf_c1_det_context_conv1_bn with operator BatchNorm and index 395
# Parsing node rf_c1_det_context_conv1_relu with operator Activation and index 396
# Parsing node rf_c1_det_context_conv2_weight with operator null and index 397
# Parsing node rf_c1_det_context_conv2_bias with operator null and index 398
# Parsing node rf_c1_det_context_conv2 with operator Convolution and index 399
# Parsing node rf_c1_det_context_conv2_bn_gamma with operator null and index 400
# Parsing node rf_c1_det_context_conv2_bn_beta with operator null and index 401
# Parsing node rf_c1_det_context_conv2_bn_moving_mean with operator null and index 402
# Parsing node rf_c1_det_context_conv2_bn_moving_var with operator null and index 403
# Parsing node rf_c1_det_context_conv2_bn with operator BatchNorm and index 404
# Parsing node rf_c1_det_context_conv3_1_weight with operator null and index 405
# Parsing node rf_c1_det_context_conv3_1_bias with operator null and index 406
# Parsing node rf_c1_det_context_conv3_1 with operator Convolution and index 407
# Parsing node rf_c1_det_context_conv3_1_bn_gamma with operator null and index 408
# Parsing node rf_c1_det_context_conv3_1_bn_beta with operator null and index 409
# Parsing node rf_c1_det_context_conv3_1_bn_moving_mean with operator null and index 410
# Parsing node rf_c1_det_context_conv3_1_bn_moving_var with operator null and index 411
# Parsing node rf_c1_det_context_conv3_1_bn with operator BatchNorm and index 412
# Parsing node rf_c1_det_context_conv3_1_relu with operator Activation and index 413
# Parsing node rf_c1_det_context_conv3_2_weight with operator null and index 414
# Parsing node rf_c1_det_context_conv3_2_bias with operator null and index 415
# Parsing node rf_c1_det_context_conv3_2 with operator Convolution and index 416
# Parsing node rf_c1_det_context_conv3_2_bn_gamma with operator null and index 417
# Parsing node rf_c1_det_context_conv3_2_bn_beta with operator null and index 418
# Parsing node rf_c1_det_context_conv3_2_bn_moving_mean with operator null and index 419
# Parsing node rf_c1_det_context_conv3_2_bn_moving_var with operator null and index 420
# Parsing node rf_c1_det_context_conv3_2_bn with operator BatchNorm and index 421
# Parsing node rf_c1_det_concat with operator Concat and index 422
# Parsing node rf_c1_det_concat_relu with operator Activation and index 423
# Parsing node face_rpn_cls_score_stride8_weight with operator null and index 424
# Parsing node face_rpn_cls_score_stride8_bias with operator null and index 425
# Parsing node face_rpn_cls_score_stride8 with operator Convolution and index 426
# Parsing node face_rpn_cls_score_reshape_stride8 with operator Reshape and index 427
# Parsing node face_rpn_cls_prob_stride8 with operator SoftmaxActivation and index 428
# softmax input: Tensor("face_rpn_cls_score_reshape_stride8:0", shape=(1, 270, 240, 2), dtype=float32)
# Parsing node face_rpn_cls_prob_reshape_stride8 with operator Reshape and index 429
# Parsing node face_rpn_bbox_pred_stride8_weight with operator null and index 430
# Parsing node face_rpn_bbox_pred_stride8_bias with operator null and index 431
# Parsing node face_rpn_bbox_pred_stride8 with operator Convolution and index 432
# Parsing node face_rpn_landmark_pred_stride8_weight with operator null and index 433
# Parsing node face_rpn_landmark_pred_stride8_bias with operator null and index 434
# Parsing node face_rpn_landmark_pred_stride8 with operator Convolution and index 435
# output node names: ['face_rpn_cls_prob_reshape_stride32', 'face_rpn_cls_prob_reshape_stride16', 'face_rpn_cls_prob_reshape_stride8', 'rf_c3_det_concat_relu', 'rf_c2_det_concat_relu', 'rf_c1_det_concat_relu']
# ------------------------------Output nodes:--------------------------
# Tensor("face_rpn_cls_prob_reshape_stride32:0", shape=(1, 34, 60, 4), dtype=float32)
# Tensor("face_rpn_cls_prob_reshape_stride16:0", shape=(1, 68, 120, 4), dtype=float32)
# Tensor("face_rpn_cls_prob_reshape_stride8:0", shape=(1, 135, 240, 4), dtype=float32)
# Tensor("rf_c3_det_concat_relu:0", shape=(1, 34, 60, 64), dtype=float32)
# Tensor("rf_c2_det_concat_relu:0", shape=(1, 68, 120, 64), dtype=float32)
# Tensor("rf_c1_det_concat_relu:0", shape=(1, 135, 240, 64), dtype=float32)
# ------------------------output nodes rev:----------------------
# Tensor("face_rpn_cls_prob_reshape_stride32:0", shape=(1, 34, 60, 4), dtype=float32)
# Tensor("face_rpn_bbox_pred_stride32_rev:0", shape=(1, 34, 60, 8), dtype=float32)
# Tensor("face_rpn_landmark_pred_stride32_rev:0", shape=(1, 34, 60, 20), dtype=float32)
# Tensor("face_rpn_cls_prob_reshape_stride16:0", shape=(1, 68, 120, 4), dtype=float32)
# Tensor("face_rpn_bbox_pred_stride16_rev:0", shape=(1, 68, 120, 8), dtype=float32)
# Tensor("face_rpn_landmark_pred_stride16_rev:0", shape=(1, 68, 120, 20), dtype=float32)
# Tensor("face_rpn_cls_prob_reshape_stride8:0", shape=(1, 135, 240, 4), dtype=float32)
# Tensor("face_rpn_bbox_pred_stride8_rev:0", shape=(1, 135, 240, 8), dtype=float32)
# Tensor("face_rpn_landmark_pred_stride8_rev:0", shape=(1, 135, 240, 20), dtype=float32)
# ---------------------test inference-------------------
# inference time: 1.380843
# inference time: 0.021569
# inference time: 0.019192
# inference time: 0.018875
# inference time: 0.019338
# output node shape: (1, 4, 34, 60)
# output node shape: (1, 8, 34, 60)
# output node shape: (1, 20, 34, 60)
# output node shape: (1, 4, 68, 120)
# output node shape: (1, 8, 68, 120)
# output node shape: (1, 20, 68, 120)
# output node shape: (1, 4, 135, 240)
# output node shape: (1, 8, 135, 240)
# output node shape: (1, 20, 135, 240)
# number of variables (trainable & global): 273
